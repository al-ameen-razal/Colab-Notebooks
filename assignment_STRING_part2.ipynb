# %% [markdown]
# # part 1 : easy level

# %%
#1. Convert a number into a string.

num = 123
print(type(num))

string = str(num)
print(string, type(string))
# Out:
# <class 'int'>
# 123 <class 'str'>

# %%
#2. Extract the first three characters from the string using user input.

text = input("Enter a string: ")
print(text[:3])
# Out:
# Enter a stringalameen
# ala

# %%
#3. Get the last four characters from the string using user input.

text = input("Enter a string: ")
print(text[-4:])
# Out:
# Enter a string: 123456789
# 6789

# %%
#4. Create a string made of the first, middle and last character

text =input("Enter a string: ")
first = text[0]
last = text[-1]
if (len(text)%2) == 0:
  middle = text[(len(text)//2)-1] + text[len(text)//2]
else:
  middle = text[len(text)//2]

new = first + middle + last
print(new)
# Out:
# Enter a string: 123456
# 1346

# %%
#5. Split the string "Hello World" into a list of words.

text = "Hello World"
list1 = text.split()
print(list1, type(list1))
# Out:
# ['Hello', 'World'] <class 'list'>

# %%
#6. Join the list ["I', 'love', 'Python'] into a single string.

list1 =  ['I', 'love', 'Python']
out = " ".join(list1)
print(out, type(out))
# Out:
# I love Python <class 'str'>

# %%
#7. Write a program to print characters of a string.

text = "Hello World"
for char in text:
  print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
#8. Count the number of occurrences of the letter 'a' in the string "banana".

text = "banana"
# print(text.count("a"))

# OR

count = 0
for a in text:
  if a in "a":
    count += 1
print(count)
# Out:
# 3

# %%
#9. Write a program to get a string which is n(non-negative integer) copies of a given string.

text = input("Enter a string : ")
rep = int(input("Enter non-negative integer: "))

print(text * rep)
# Out:
# Enter a string : hello
# Enter non-negative integer: 3
# hellohellohello

# %%
#10. Test if string is subset of another.

text = "alameen kk kandamangalth edathala"
word = input("Enter a string: ")
if word in text:
  print(word, "is a subset of", "'",text,"'")
else:
  print(word, "is not a subset of", text)
# Out:
# Enter a string: kk
# kk is a subset of ' alameen kk kandamangalth edathala '

# %%
#11. Check if given string can be formed by concatenating 2 other strings.

mainstring = input("Enter the parent string : ")
firststring = input("Enter the 1st child string : ")
secondstring = input("Enter the 2nd child string : ")

if firststring + secondstring == mainstring:
  print("Parent string CAN BE FORMED by concatenating 2 child strings")
else:
  print("Parent string CAN NOT BE FORMED by concatenating 2 child strings")
# Out:
# Enter the parent string : love
# Enter the 1st child string : lo
# Enter the 2nd child string : ve
# Parent string CAN BE FORMED by concatenating 2 child strings

# %% [markdown]
# # part 2

# %%
#1. Program to check whether a string is palindrome or not.

string1 = input("Enter a Palindrome text : ")
if string1[:]==string1[::-1]:
  print("You entered a palindrome text")
else:
  print("You entered a non-palindrome text")
# Out:
# Enter a Palindrome text : malayalam
# You entered a palindrome text

# %%
#2. Swap one word with other word in a string. Both the words are entered by the user.

text = input("Enter a setence : ")
word1 = input("Enter the word to be change : ")
word2 = input("Enter the new word :")
text = text.replace(word1,word2).capitalize()

print(text)
# Out:
# Enter a setence : I had a car. you had a bike.
# Enter the word to be change : have
# Enter the new word :had
# I had a car. you had a bike.

# %%
#3. Write a Python program to get a string made of the first 2 and last 2 characters of a given string.
#   If the string length is less than 2, return the empty string instead.

text = input("Enter a text a minimum length of 2 : ")
if len(text) >= 2:
  print(text[:2] + text[-2:])
else:
  print(str('""'))
# Out:
# Enter a text a minimum length of 2 : beautiful
# beul

# %%
#4. Given a string of numeric digits like "12345", calculate and display the sum of the digits.

string1 = input("Enter the numeric string : ")
sum = 0

for i in string1:
  sum += int(i)
print("Sum = ",sum)
# Out:
# Enter the numeric string : 1234
# Sum =  10

# %%
#5 Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string
# already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.

text = input("Enter a text : ")
if len(text) >= 3:
  if text[-3:] == "ing":
    text += "ly"
  else:
    text += "ing"
  print(text)
else:
  print("Length of Etnry should be at least 3")
# Out:
# Enter a text : dancing
# dancingly

# %%
#6 Write a Program to get a string made of 4 copies of the last two characters of a specified string (length must be at least 2).

sentence = input("Enter the sentence : ")
if len(sentence) >= 2:
  print((sentence[-2:])*4)
else:
  print("Sentence length must be at least 2")
# Out:
# Enter the sentence : PANAMA
# MAMAMAMA

# %%
#7 Write a Python program to get a string made of the first three characters of a specified string.
#   If the length of the string is less than 3, return the original string.

sentence = input("Enter a string: ")
if len(sentence) < 3:
  print(sentence)
else:
  print(sentence[:3])
# Out:
# Enter a string: how
# how

# %%
#8 Write a Python program to reverse a string if its length is a multiple of 4.

sentance = input("Enter a sentance : ")
if len(sentance)%4 == 0:
  print(sentance[::-1])
else:
  print("To reverse the sentance, the length of the sentance should multiple of 4")
# Out:
# Enter a sentance : harikrishnan
# nanhsirkirah

# %%
#9. Write a Python program to check whether a string starts with specified characters.
#   (dont use builtin function)

print("Check whether a sentence starts with specified characters")
text = input("Type sentence here: ")
test = input("Type specified character here: ")
testlen = 0

for i in test:
  testlen += 1

if test[:testlen] == text[:testlen]:
  print("YES",text,"starts with", test)
else:
  print("NO",text,"not starts with", test)
# Out:
# Check whether a sentence starts with specified characters
# Type sentence here: SIGN LOGISTICS
# Type specified character here: ETHICS
# NO SIGN LOGISTICS not starts with ETHICS

# %%
#10. Program to accept the strings which contain all vowels.

sentence = input("Enter a sentence : ")
vowel = "aeiou"
for i in vowel:
  if i in sentence.lower():
    flag = True
  else:
    flag = False
    break
if flag:
  print("All vowels occured")
else:
  print("Not all vowels occured")
# Out:
# Enter a sentence : AJHHBSeisou
# All vowels occured

# %%
#11. Program to count number of vowels in a given string.

sentence = "Hi, how are you!!"
vow = "AEIOUaeiou"
count = 0
for i in sentence:
  if i in vow:
    count += 1
print(count)
# Out:
# 6

# %%
#12. Write a Python program that prompts the user to enter a sentence and counts the number of vowels in the sentence.

sentence = input("Enter a sentence : ")
count = 0

for vow in sentence:
  if vow in "aeiouAEIOU":
    count += 1
print(count, "vowels in", sentence)
# Out:
# Enter a sentence : hi hello how are you
# 8 vowels in hi hello how are you

# %%
# 13. Write a python program to get a new string from a given string where "is" has been added to the front.
#     If the given string already begins with "is" then return the string unchanged.

text = input("Enter a sentence : ")
list1 = text.split()
result = ""
out = ""

if "is" in list1:
  for i in list1:
    while i != "is":
      result += " "+i
      break
  out += i + result
print(out)

#OR

text = input("\nEnter a sentence : ")
rsult = ""
position = text.find("is")
if "is" in text:
  result = "is " + text[:position] + text[position+3:]
  print(result)
else:
  print(text)
# Out:
# Enter a sentence : How about isotopes is
# is How about isotopes
#
# Enter a sentence : he is a man
# is he a man

# %%
# 14. Write a program to reverse each character of a string using while loop.

sentence = input("Enter a sentence : ")
lastchar = len(sentence) - 1
result = ""

while lastchar >= 0:
  result += sentence[lastchar]
  lastchar -= 1

print(result)
# Out:
# Enter a sentence : erakkahc ih
# hi chakkare

# %%
# 15. Write a program to count occurrences of all characters within a string

sentence = input("Enter a sentence : ")
cache = ""
for i in sentence:
  if i not in cache:
    count = sentence.count(i)
    print(i, "->", count, "times repeated")
    cache += i
# Out:
# Enter a sentence : alameen
# a -> 2 times repeated
# l -> 1 times repeated
# m -> 1 times repeated
# e -> 2 times repeated
# n -> 1 times repeated

# %%
# 16. Write a program that takes a string input and counts the number of vowels and consonants.

sentence = input("Enter a sentence : ").lower()
c_vow, c_con = 0, 0
for letter in sentence:
  if "a"<= letter <="z":
    if letter in "aeiouAEIOU":
      c_vow += 1
    else:
      c_con += 1

if c_con == 0  and c_vow == 0:
  print("No consonants and vowels in", sentence)
else:
  print("Vowel count = ", c_vow)
  print("Consonant count = ", c_con)
# Out:
# Enter a sentence : AAAAAAAAAAR
# Vowel count =  10
# Consonant count =  1

# %%
# 17. Write a program to remove duplicate characters from a string.

sentence = input("Enter a sentnece : ")
out = []

for char in sentence:
  if char not in out:
    out.append(char)
print(" ".join(out))
# Out:
# Enter a sentnece : hi hello how are you today
# h i   e l o w a r y u t d

# %%
# 18. Write a program to reverse the order of words in a sentence

sentence = input("Enter a sentence : ")
list1 = sentence.split()

for i in list1:
  rev = i[::-1]
  print(rev,end=" ")
# Out:
# Enter a sentence : hi hello how are you today
# ih olleh woh era uoy yadot

# %%
# 19. Write a program to find and count all valid palindromic substrings in a given string.

sentence = input("Enter your thoughts: ")
list1 = sentence.split()
count = 0

for i in list1:
  if i == i[::-1]:
    count += 1
    print(i)
print("Total count of palindromic words in your thoughts:- ", count)
# Out:
# Enter your thoughts: hello malayalam guy you are refer to our company.
# malayalam
# refer
# Total count of palindromic words in your thoughts:-  2

# %%
# 20. Write a program that takes two strings as input and finds the common characters between them.

word1 = input("Enter the first sentence : ")
word2 = input("Enter the second sentence : ")
set1 = set(word1)
set2 = set(word2)
print("Common charector : ",set1&set2)

# OR

cache = ""
shorter = (min(word1,word2))
larger = max(word1,word2)
print("\nCommon characters:- ")
for i in shorter:
  if i in larger:
    if i not in cache:
      print(i,end=",")
      cache += i
# Out:
# Enter the first sentence : hello
# Enter the second sentence : how are you hello
# Common charector :  {'l', 'o', 'h', 'e'}
#
# Common characters:-
# h,e,l,o,

# %% [markdown]
# # part 3

# %%
# 1. Write a Python program that asks the user to enter a string and checks if it's an isogram.
#     An isogram is a word or phrase without any repeating letters.

text = input("Type the word here: ")
testing = text.lower().replace(" ", "")
flag = True

for i in range(len(testing)):
    for j in range(i + 1, len(testing)):
        if testing[i] == testing[j]:
            flag = False
            break

if flag:
    print("YES,'",text,"' is an isogram.")
else:
    print("NO,'",text,"' is not an isogram.")
# Out:
# Type the word here: banana
# NO,' banana ' is not an isogram.

# %%
# 2. Write a Python program that prompts the user to enter a string , and checks if it's a Disemvowelled string.
#     A Disemvowelled string is a string from which all the vowels have been removed.

sentence = input("Enter a word or a sentence: ").lower().replace(" ","")
flag = True
for i in sentence:
  if i in "aeiou":
    flag = False
    break
if flag:
  print(sentence,"is Disemvowelled")
else:
  print(sentence,"is NOT Disemvowelled")
# Out:
# Enter a word or a sentence: python
# python is NOT Disemvowelled

# %%
# 3. Program to find the first non-repeating character in a string
#    Input "aabbccdeeff" Output→ 'd'

string1 = input("Eenter a string : ")

for i in string1:
  if string1.count(i) == 1:
    print(i)
    break
# Out:
# Eenter a string : aabccddef
# b

# %%
# 4. Program to check if two strings are rotations of each other
#    Input→ "abcd" and "cdab" Output→ True

string1 = input("Enter 1st string : ")
string2 = input("Enter 2nd stirng : ")
if sorted(string1) == sorted(string2):
  print("True")
else:
  print("False")
# Out:
# Enter 1st string : al ameen
# Enter 2nd stirng : amal een
# True

# %%
# 5. Program to find all the substrings of a given string.
#    Input→ "abc" Output→ ['a', 'b', 'c', 'ab', 'bc', 'abc']

# %%
# 6. Program to check if the given string is a pangram. A pangram contains all letters from A-Z at least once.
#    Example: Input→ "The quick brown fox jumps over the lazy dog"  output-> True

sentence = set(input("Enter a senctence : ").lower().replace(" ", ""))
alphabets = "abcdefghijklmnopqrstuvwxyz"

if len(sentence) == len(alphabets):
  print("It's a Pangram")
else:
  print("It's not a Pangram")
# Out:
# Enter a senctence : The quick brown fox jumps over the lazy dog
# It's a Pangram

# %%
# 7. Find the longest palindrome substring in a string
#    Example: Input→ "babad" Output→ "bab" or "aba"


sentence = input("Enter a string : ")
pal_length = 0
out = ""
word = ""

for i in sentence.lower():
  word += i
  if word == word[::-1] and len(word) > pal_length:
    pal_length = len(word)
    out = word
print(out)
# Out:
# bab

# %%
# 8. Replace all repeated characters in a string with * (except the first occurrence
# Input→ "programming" Output→ "prog*am*n*"

# %%
# 9. Check if a string has balanced parentheses (), (}. []
#    Input→ "{[()]" Output→ Balanced

# %%
# 10. Remove all characters except alphabets
#     Input→ "Pyt@#hon123" Output→ "Python"

# %%
# 11. Find the frequency of each word and print the top 3 most frequent words
#     Input→ "cat dog cat mouse cat dog"
#     Output→ cat: 3  dog: 2  mouse: 1
