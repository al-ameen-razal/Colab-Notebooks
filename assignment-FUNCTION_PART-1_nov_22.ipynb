# %% [markdown]
# ## FUNCTION

# %% [markdown]
# ### SET1

# %% [markdown]
# 1. Create a function called calculate_area that takes the length and width of a rectangle as input and returns its area. Test the function with different length and width values.

# %%
def calculate_area(a,b):
  return a * b

length = float(input("Enter the length of Rectangle: "))
width = float(input("Enter the width of Rectangle: "))
area = calculate_area(length, width)
print("Area = ",area)
print()
print("Area = ",calculate_area(2, 8))
print("Area = ",calculate_area(12, 3))
# Out:
# Enter the length of Rectangle: 5
# Enter the width of Rectangle: 6
# Area =  30.0
#
# Area =  16
# Area =  36

# %% [markdown]
#  2. Create a function called average_list that takes a list of numbers as input and returns their average

# %%
def average_list(number_list):
  return sum(number_list)/len(number_list)

print(average_list([1, 2, 3]))
print(average_list([1, -2, 3]))
# Out:
# 2.0
# 0.6666666666666666

# %% [markdown]
# 3. Write a function that takes a list of numbers and returns a tuple containing the sum and average of the numbers. Call the function and print the returned tuple.

# %%
def tuple_sum_and_avg(number_list):
  return f"Sum = {sum(number_list)}", f"Average = {len(number_list)}"

result = tuple_sum_and_avg([1, 2, 3])
print(result, type(result))
# Out:
# ('Sum = 6', 'Average = 3') <class 'tuple'>

# %% [markdown]
# 4. Create a function that takes multiple arguments and returns them as a tuple. Call the function with different arguments and unpack the returned tuples into separate variables. Print the variables.

# %%
def tuple_seperater():

# %% [markdown]
# 5. Write a Python function to check whether a number falls within a given range.

# %%
def range_cehcker(num):
    if 1<= num <=10:
        return f"{num} in the range"
    return f"{num} not in the range"

print(range_cehcker(11))
# Out:
# 11 not in the range

# %% [markdown]
# 6. Write a Python function to create and print a list where the values are the squares of numbers between 1 and 30 (both included).

# %% [markdown]
# 7.  Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number as an argument.

# %% [markdown]
# 8. Write a function called is_prime that takes an integer as input and returns True if the number is prime and False otherwise. Test the function with both prime and non-prime numbers.

# %% [markdown]
# 9. Find out highest common factor (HCF) or greatest common factor of two input numbers. (using function).

# %% [markdown]
# 10. Write a function called is_palindrome that takes an integer as input and returns True if the number is palindrome and False otherwise

# %% [markdown]
# ### SET2

# %% [markdown]
# 1. Enter your car number (only number part), then enter day number starting from 1 to 7 (day number of the week ). Your program should say you should go out in your car or not. All even day numbers are mean for cars with even numbers and odd car numbers are for odd day numbers. (Use function).

# %% [markdown]
# 2. Write a function called count_letters that takes a string as input and returns a dictionary with the count of each letter.

# %% [markdown]
# 3. Write a function called even even_squares that takes a list of numbers and returns a new list containing the squares of even numbers only,

# %% [markdown]
# 4. Write a Python program to reverse a string.

# %% [markdown]
# 5. Write a Python function to sum all the numbers in a list.

# %% [markdown]
# 6. Write a Python function that accepts a string and counts the number of upper and lower case letters.

# %% [markdown]
# 7. Write a program to find missing numbers in a given list of integers from 1 to n.
# Input: [1, 2, 4, 6, 7, 9, 10], n = 10
# Output: [3, 5, 8]

# %% [markdown]
# 8. Implement a function that compresses a string using the counts of repeated characters.
# Input: "aaabbbcc"
# Output: "a3b3c2"

# %% [markdown]
# ### SET3

# %% [markdown]
# 1. Write a function called reverse_list that takes a list as input and returns the reversed version of that list.

# %% [markdown]
# 2. Create a function convert_to_fahrenheit that takes a temperature in Celsius and returns the temperature in Fahrenheit.

# %% [markdown]
# 3. Write a function find_duplicates that takes a list and returns a set of duplicate elements.

# %% [markdown]
# 4. Write a function count_words that takes a string and returns a dictionary containing the word count of each unique word in the string.

# %% [markdown]
# 5. Create a function longest word that takes a list of words and returns the longest word.

# %% [markdown]
# 6. Write a function called sort_list that takes a list of numbers and returns the sorted list in ascending order.

# %% [markdown]
# 7. Create a function remove_vowels that takes a string and returns the string with all vowels removed.

# %% [markdown]
# 8. Write a function generate_fibonacci that generates a Fibonacci series up to a given number n

# %% [markdown]
# 9. Write a function called is_anagram that checks whether two strings are anagrams of each other.

# %% [markdown]
# 10. Create a function generate_password that generates a random password of a given length

# %% [markdown]
# ### SET4

# %% [markdown]
# 1. Write a function find_second_largest that takes a list of numbers and returns the second largest number.

# %% [markdown]
# 2. Create a function sum_of_digits that takes an integer and returns the sum of its digits.

# %% [markdown]
# 3. Write a function is_armstrong that checks whether a given number is an Armstrong number or not

# %% [markdown]
# 4. Write a function replace_substring that replaces all occurrences of a given substring in a string with another substring.

# %% [markdown]
# 5. Create a function remove_duplicates that takes a list and returns a new list with duplicate elements removed.

# %% [markdown]
# 6. Write a function calculate_discount that takes the original price and discount percentage as input and returns the discounted price.

# %% [markdown]
# 7. Create a function find_common_elements that takes two lists and returns a list of common elements.

# %% [markdown]
# 8. Write a function capitalize_words that takes a string and returns the string with the first letter of each word capitalized.

# %% [markdown]
# 9. Write a function get_unique_elements that takes a list and returns a list of unique elements without changing their order.

# %%
10. Write a function sum_even_numbers that takes a list of numbers and returns the sum of only the even numbers.
